# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
d = pd.read_excel('C:/Users/praka/Desktop/mavoix/Data_Science_2020_v2.xlsx')

# %%
d
# Out:
#     Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0           DS0001    Bangalore                  1                         0
# 1           DS0002       Mumbai                  2                         1
# 2           DS0003       Mumbai                  2                         0
# 3           DS0004      Dhanbad                  2                         0
# 4           DS0005    Bangalore                  2                         0
# ..             ...          ...                ...                       ...
# 606         DS0607         Pune                  2                         2
# 607         DS0608    Bangalore                  1                         0
# 608         DS0609        Delhi                  2                         2
# 609         DS0610    Bangalore                  3                         2
# 610         DS0611     Thrissur                  2                         2
#
#      Data Science (out of 3)  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 14 columns):
# Application_ID                611 non-null object
# Current City                  611 non-null object
# Python (out of 3)             611 non-null int64
# R Programming (out of 3)      611 non-null int64
# Data Science (out of 3)       611 non-null int64
# Other skills                  601 non-null object
# Institute                     611 non-null object
# Degree                        575 non-null object
# Stream                        580 non-null object
# Current Year Of Graduation    611 non-null int64
# Performance_PG                128 non-null object
# Performance_UG                533 non-null object
# Performance_12                363 non-null object
# Performance_10                339 non-null object
# dtypes: int64(4), object(10)
# memory usage: 67.0+ KB

# %%
for i in d.head().iterrows():
    print(i)
# Out:
# (0, Application_ID                                                           DS0001
# Current City                                                          Bangalore
# Python (out of 3)                                                             1
# R Programming (out of 3)                                                      0
# Data Science (out of 3)                                                       3
# Other skills                  Machine Learning, Arduino, C Programming, CSS,...
# Institute                                          Global Academy of Technology
# Degree                                            Bachelor of Engineering (B.E)
# Stream                                   Electrical and Electronics Engineering
# Current Year Of Graduation                                                 2019
# Performance_PG                                                              NaN
# Performance_UG                                                          7.73/10
# ...

# %%
d.head(1)['Python (out of 3)'].values[0]
# Out:
# 1

# %%
d.head(1)['Degree'].values[0]
# Out:
# 'Bachelor of Engineering (B.E)'

# %%
d.head(1)['Other skills'][0]
# Out:
# 'Machine Learning, Arduino, C Programming, CSS, Data Analytics, Data Structures, Deep Learning, HTML, Natural Language Processing (NLP), MATLAB, Python'

# %%
skills=[]
for i in range(len(d)):
    os=d.iloc[i]['Other skills']
    if(type(d.iloc[i]['Other skills']) == str):
        os = os.split(', ')
        for j in os:
            if j not in skills:
                skills.append(j)

# %%
type(d.iloc[26]['Other skills']) == str
# Out:
# True

# %%
skills
# Out:
# ['Machine Learning',
#  'Arduino',
#  'C Programming',
#  'CSS',
#  'Data Analytics',
#  'Data Structures',
#  'Deep Learning',
#  'HTML',
#  'Natural Language Processing (NLP)',
#  'MATLAB',
#  'Python',
#  'AutoCAD',
#  'MS-Office',
#  'Microsoft Azure',
#  'MySQL',
#  'SolidWorks',
#  'R Programming',
#  'C++ Programming',
#  'Image Processing',
#  'Algorithms',
#  'Computer Vision',
#  'Java',
#  'Android',
#  'MS-Word',
#  'SQL',
#  'MS-Excel',
#  'GitHub',
#  'JavaScript',
#  'STATA',
#  'OpenCV',
#  'PostgreSQL',
#  'English Proficiency (Spoken)',
#  'SPSS',
#  'Data Science',
#  'Eclipse (IDE)',
#  'Database Management System (DBMS)',
#  'Linux',
#  'Catia',
#  'Statistical Modeling',
#  'Tableau',
#  'Embedded Systems',
#  'Bootstrap',
#  'Flask',
#  'LARAVEL',
#  'Node.js',
#  'PHP',
#  'Stripe Payment API',
#  'Video Editing',
#  'Heroku',
#  'Unix',
#  'Amazon Web Services (AWS)',
#  'Apache Cassandra',
#  'Apache Kafka',
#  'BIG DATA ANALYTICS',
#  'Cloud Computing',
# ...

# %%
len(skills)
# Out:
# 166

# %%
Other_skills=['Amazon Web Services (AWS)','MS SQL Server','SQLite','Neural Networks','Amazon Web Server (AWS)','NoSQL','Machine Learning','Deep Learning','Natural Language Processing (NLP)','MySQL','SQL','MS-Excel','PostgreSQL','Statistical Modeling']

# %%
w=[]
for i in range(len(d)):
    weightage = 0

    if(d.iloc[i]['Python (out of 3)']==3):
        weightage +=10
    elif(d.iloc[i]['Python (out of 3)']==2):
        weightage += 7
    elif(d.iloc[i]['Python (out of 3)']==1):
        weightage += 3
    print('Python : ',weightage)


    if(d.iloc[i]['R Programming (out of 3)']==3):
        weightage +=10
    elif(d.iloc[i]['R Programming (out of 3)']==2):
        weightage += 7
    elif(d.iloc[i]['R Programming (out of 3)']==1):
        weightage += 3
    print('R : ',weightage)


    if(d.iloc[i]['Data Science (out of 3)']==3):
        weightage +=10
    elif(d.iloc[i]['Data Science (out of 3)']==2):
        weightage += 7
    elif(d.iloc[i]['Data Science (out of 3)']==1):
        weightage += 3
    print('DS : ',weightage)


    if((d.iloc[i]['Degree']=='Bachelor of Engineering (B.E)') or (d.iloc[i]['Degree']=='Bachelor of Technology (B.Tech)') or (d.iloc[i]['Degree']=='B.Tech (Hons.)') or (d.iloc[i]['Degree']=='Integrated B.Tech')):
        if(d.iloc[i]['Current Year Of Graduation'] == 2020 ):
            weightage += 10
        if(d.iloc[i]['Current Year Of Graduation'] == 2019 ):
            weightage += 8
        if(d.iloc[i]['Current Year Of Graduation'] <= 2018 ):
            weightage += 5

    if((d.iloc[i]['Degree']=='Integrated M.Tech') or (d.iloc[i]['Degree']=='Master of Science (M.Sc)') or (d.iloc[i]['Degree']=='Master of Technology (M.Tech)') or (d.iloc[i]['Degree']=='Integrated M.Sc.') or (d.iloc[i]['Degree']=='Master of Science (M.Sc) (Hons.)')):
        if(d.iloc[i]['Current Year Of Graduation'] == 2020 ):
            weightage += 7
        if(d.iloc[i]['Current Year Of Graduation'] <= 2019 ):
            weightage += 3

    print(weightage)

    os=d.iloc[i]['Other skills']
    if(type(os) == str):
        os = os.split(', ')
        for j in os:
            if j in Other_skills:
                print(j)
                weightage += 3
    w.append(weightage)
# Out:
# Python :  3
# R :  3
# DS :  13
# 21
# Machine Learning
# Deep Learning
# Natural Language Processing (NLP)
# Python :  7
# R :  10
# DS :  17
# 17
# Machine Learning
# MySQL
# Deep Learning
# Python :  7
# R :  7
# DS :  7
# 12
# Python :  7
# R :  7
# DS :  14
# 14
# Natural Language Processing (NLP)
# Deep Learning
# Machine Learning
# MySQL
# Python :  7
# R :  7
# DS :  7
# 12
# SQL
# MS-Excel
# Python :  7
# R :  14
# DS :  14
# 14
# SQL
# Python :  0
# R :  0
# DS :  3
# 3
# Deep Learning
# Machine Learning
# Python :  7
# R :  14
# DS :  14
# 19
# Natural Language Processing (NLP)
# SQL
# Python :  7
# R :  7
# DS :  10
# 10
# MySQL
# Deep Learning
# Machine Learning
# Python :  0
# R :  0
# DS :  0
# 0
# PostgreSQL
# Python :  3
# R :  3
# DS :  6
# 6
# MS-Excel
# Machine Learning
# Python :  3
# R :  10
# DS :  17
# 20
# MS-Excel
# Machine Learning
# SQL
# Python :  0
# R :  0
# DS :  0
# 5
# SQL
# Python :  0
# R :  0
# DS :  0
# 5
# Python :  10
# R :  10
# DS :  20
# 20
# ...

# %%
type(d.head(1)['Other skills'].values[0])
# Out:
# str

# %%
d.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         DS0001    Bangalore                  1                         0
# 1         DS0002       Mumbai                  2                         1
# 2         DS0003       Mumbai                  2                         0
# 3         DS0004      Dhanbad                  2                         0
# 4         DS0005    Bangalore                  2                         0
#
#    Data Science (out of 3)                                       Other skills  \
# 0                        3  Machine Learning, Arduino, C Programming, CSS,...
# 1                        2  AutoCAD, MS-Office, Machine Learning, Microsof...
# 2                        0  C++ Programming, Data Structures, Image Proces...
# 3                        2  Algorithms, C++ Programming, Data Structures, ...
# 4                        0                     MS-Word, Python, SQL, MS-Excel
#
# ...

# %%
d.head(1)['Python (out of 3)'].values[0]
# Out:
# 1

# %%
d.iloc[0]['Python (out of 3)']
# Out:
# 1

# %%
d.iloc[0]['Other skills']
# Out:
# 'Machine Learning, Arduino, C Programming, CSS, Data Analytics, Data Structures, Deep Learning, HTML, Natural Language Processing (NLP), MATLAB, Python'

# %%
d.iloc[0]['Weightage']=21
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
d.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         DS0001    Bangalore                  1                         0
# 1         DS0002       Mumbai                  2                         1
# 2         DS0003       Mumbai                  2                         0
# 3         DS0004      Dhanbad                  2                         0
# 4         DS0005    Bangalore                  2                         0
#
#    Data Science (out of 3)                                       Other skills  \
# 0                        3  Machine Learning, Arduino, C Programming, CSS,...
# 1                        2  AutoCAD, MS-Office, Machine Learning, Microsof...
# 2                        0  C++ Programming, Data Structures, Image Proces...
# 3                        2  Algorithms, C++ Programming, Data Structures, ...
# 4                        0                     MS-Word, Python, SQL, MS-Excel
#
# ...

# %%
len(w)
# Out:
# 611

# %%
d['Weightage'] = w

# %%
d.head()
# Out:
#   Application_ID Current City  Python (out of 3)  R Programming (out of 3)  \
# 0         DS0001    Bangalore                  1                         0
# 1         DS0002       Mumbai                  2                         1
# 2         DS0003       Mumbai                  2                         0
# 3         DS0004      Dhanbad                  2                         0
# 4         DS0005    Bangalore                  2                         0
#
#    Data Science (out of 3)                                       Other skills  \
# 0                        3  Machine Learning, Arduino, C Programming, CSS,...
# 1                        2  AutoCAD, MS-Office, Machine Learning, Microsof...
# 2                        0  C++ Programming, Data Structures, Image Proces...
# 3                        2  Algorithms, C++ Programming, Data Structures, ...
# 4                        0                     MS-Word, Python, SQL, MS-Excel
#
# ...

# %%
d.to_csv('Weightages.csv')

# %%
df = d.drop(columns=['Application_ID','Current City','Institute','Stream','Performance_12','Performance_10'],axis=1)

# %%
df
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills  \
# ...

# %%
s = []
for i in range(len(df)):
    if(df.iloc[i]['Weightage']>=40):
        s.append(1)
    else:
        s.append(0)

# %%
len(s)
# Out:
# 611

# %%
df['Class'] = s

# %%
df
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                                           Other skills  \
# ...

# %%
skills_count=[]
for i in range(len(df)):
    count=0
    os=df.iloc[i]['Other skills']
    if(type(os) == str):
        os = os.split(', ')
        for j in os:
            if j in Other_skills:
                count +=1
    skills_count.append(count)

# %%
skills_count
# Out:
# [3,
#  3,
#  0,
#  4,
#  2,
#  1,
#  2,
#  2,
#  3,
#  1,
#  2,
#  3,
#  1,
#  0,
#  3,
#  0,
#  4,
#  1,
#  3,
#  2,
#  1,
#  0,
#  2,
#  2,
#  4,
#  0,
#  3,
#  2,
#  1,
#  0,
#  2,
#  2,
#  1,
#  2,
#  3,
#  3,
#  1,
#  1,
#  0,
#  2,
#  4,
#  1,
#  5,
#  2,
#  4,
#  0,
#  4,
#  1,
#  0,
#  1,
#  3,
#  3,
#  2,
#  5,
#  3,
#  0,
#  0,
#  2,
#  1,
#  2,
#  2,
#  0,
#  2,
#  1,
#  1,
#  0,
#  4,
#  1,
#  1,
#  2,
#  2,
#  3,
#  4,
#  2,
#  1,
#  3,
#  3,
#  2,
#  1,
#  1,
#  1,
#  3,
#  5,
#  2,
#  4,
#  5,
#  2,
#  2,
#  0,
#  1,
#  4,
#  1,
#  2,
#  1,
#  2,
#  2,
#  4,
#  2,
#  5,
#  4,
#  3,
#  3,
#  4,
#  1,
#  3,
#  1,
#  3,
#  1,
#  0,
#  2,
#  3,
#  2,
#  2,
#  0,
#  2,
#  1,
#  0,
#  2,
#  2,
#  2,
#  0,
#  3,
#  4,
#  4,
#  1,
#  1,
#  3,
#  2,
#  3,
#  4,
#  1,
#  2,
#  2,
#  3,
#  1,
#  5,
#  3,
#  2,
#  3,
#  0,
#  5,
#  2,
#  3,
#  2,
#  5,
#  2,
#  2,
#  4,
#  2,
#  4,
#  2,
#  0,
#  2,
#  1,
#  4,
#  1,
#  2,
#  5,
#  2,
#  1,
#  1,
#  3,
#  5,
#  3,
#  2,
#  5,
# ...

# %%
df=df.drop(columns=['Other skills','Performance_PG','Performance_UG'],axis=1)

# %%
df['Skills Count'] = skills_count

# %%
df
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#                               Degree  Current Year Of Graduation  Weightage  \
# ...

# %%
deg=[]
for i in range(len(df)):
    if((d.iloc[i]['Degree']=='Bachelor of Engineering (B.E)') or (d.iloc[i]['Degree']=='Bachelor of Technology (B.Tech)') or (d.iloc[i]['Degree']=='B.Tech (Hons.)') or (d.iloc[i]['Degree']=='Integrated B.Tech')):
        deg.append(1)
    elif((d.iloc[i]['Degree']=='Integrated M.Tech') or (d.iloc[i]['Degree']=='Master of Science (M.Sc)') or (d.iloc[i]['Degree']=='Master of Technology (M.Tech)') or (d.iloc[i]['Degree']=='Integrated M.Sc.') or (d.iloc[i]['Degree']=='Master of Science (M.Sc) (Hons.)')):
        deg.append(2)
    else:
        deg.append(0)

# %%
len(deg)
# Out:
# 611

# %%
df['Degree']=deg

# %%
df
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#      Degree  Current Year Of Graduation  Weightage  Class  Skills Count
# ...

# %%
yr = df['Current Year Of Graduation']

# %%
yr[0]
# Out:
# 2019

# %%
from sklearn.linear_model import LogisticRegression

# %%
X = df.drop(columns=['Class','Weightage'])
y = df['Class']

# %%
X
# Out:
#      Python (out of 3)  R Programming (out of 3)  Data Science (out of 3)  \
# 0                    1                         0                        3
# 1                    2                         1                        2
# 2                    2                         0                        0
# 3                    2                         0                        2
# 4                    2                         0                        0
# ..                 ...                       ...                      ...
# 606                  2                         2                        2
# 607                  1                         0                        0
# 608                  2                         2                        0
# 609                  3                         2                        2
# 610                  2                         2                        0
#
#      Degree  Current Year Of Graduation  Skills Count
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 606    1
# 607    0
# 608    0
# 609    1
# 610    0
# Name: Class, Length: 611, dtype: int64

# %%
clf = LogisticRegression(random_state=0).fit(X, y)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
clf.score(X, y)
# Out:
# 0.983633387888707

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
clf = LogisticRegression(random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9891304347826086

# %%
clf.predict([[2,2,2,1,2020,6]])
# Out:
# array([1], dtype=int64)

# %%
X_test.iloc[0]
# Out:
# Python (out of 3)                2
# R Programming (out of 3)         0
# Data Science (out of 3)          2
# Degree                           0
# Current Year Of Graduation    2017
# Weightage                       23
# Skills Count                     3
# Name: 81, dtype: int64

# %%
y_test.iloc[0]
# Out:
# 0

# %%
from sklearn.externals import joblib

# %%
joblib.dump(clf, 'logistic.pkl')
# Out:
# ['logistic.pkl']

# %%
model = loaded_model = joblib.load('logistic.pkl')

# %%
model.predict([[2,2,2,1,2020,6]])[0]
# Out:
# 1

# %%
df.to_csv('Processed_Info.csv')
